# %% [markdown]
# <a href="https://colab.research.google.com/github/shahabday/graph-neural-networks/blob/main/3_NodeClassificationPyG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Please, make a copy of the notebook before we start.
# Turn on the GPU support in the Runtime/Change runtime type.
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# Install Pytorch Geometric and its dependencies
# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(h.detach().cpu().numpy())

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()

def visualize_both(h1, h2, title1, title2, color):
    z1 = TSNE(n_components=2).fit_transform(h1.detach().cpu().numpy())
    z2 = TSNE(n_components=2).fit_transform(h2.detach().cpu().numpy())

    fig, ax = plt.subplots(1, 2, figsize=(20, 10))

    ax[0].scatter(z1[:, 0], z1[:, 1], s=70, c=color, cmap="Set2")
    ax[0].set_title(title1)
    ax[0].set_xticks([])
    ax[0].set_yticks([])

    ax[1].scatter(z2[:, 0], z2[:, 1], s=70, c=color, cmap="Set2")
    ax[1].set_title(title2)
    ax[1].set_xticks([])
    ax[1].set_yticks([])

    plt.show()
# Out:
# 2.5.1+cu124
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 22.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 52.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 15.0 MB/s eta 0:00:00
#   Building wheel for torch-geometric (pyproject.toml) ... done

# %% [markdown]
# # **Transductive & Inductive learning on graphs**
#
# >"[Transductive inference](https://en.wikipedia.org/wiki/Transduction_(machine_learning)) is reasoning from observed, specific (training) cases to specific (test) cases." \
# >Inductive inference "is reasoning from observed training cases to general rules, which are then applied to the test cases."
#
# What does it actually mean?
#
#
# <center width="100%" style="padding:10px"> <img src ="https://drive.google.com/uc?id=1IkDcHZ9x0mdBsiFiLjHlgoykThitQyMi" width="600px"></center>
#
#
# Inductive inference  | Transductive inference
# -------------------|------------------
# Train the model and label unlabelled points which we **have never encountered**. | Train the model and label unlabelled points which we **have already encountered**.
# **Use the initially trained model** for prediction of new unlabelled points. | **Retrain the model** to predict new unlabelled points.
# Can predict **any point** in the feature space. | Can predict **only the points encountered in the test dataset**.
# **Less** computational costs. | Can become **more** computationally costly.

# %% [markdown]
# #### **GCN layer revisited**
#
# Let's have a look at the GCN layer one more time:
# * $\hat A = A + I$ - sum of the adjacency matrix and an identity matrix. $\hat A \in R^{N \times N}$
# * $\hat D$ - a diagonal node degree matrix of $\hat A$.
#
# $$H^{l+1} = \sigma\left(\hat{D}^{-1/2}\hat{A}\hat{D}^{-1/2}H^{l}W^{l}\right)$$
#
# **The adjacency matrix is inside the formula of the update rule!**
#
# **<font color='red'>The nature of the GCN layer is that it only* works in the transductive setting.</font>**
#
# Consequences:
#
# *   It's impossible to classify a newly added node without retraining the model, since the size of the adjacency matrix would change.
# *   Even if we use the trained model with the graph of the same size the predictions would be meaningless, since the adjacency matrix would contain different entries.
#
# **What do we need to do to be able to use a trained model with a completely different graph?**
#
# *   Implement the GCN layer in a form that allows to use inductive learning**. (Check PyG implementations).
# *   Use differrent algorithms, e.g. [generalized message passing algorithm from DeepMind](https://arxiv.org/abs/1806.01261). We will do it in the next colab.
#
#
# \* It depends on the implementation. PyG implementation allows it to work in the inductive setting out of the box. \
# \** It's not guaranteed that the results on the unseen data would be any good because of the nature of graph convolutions that can be represented as polynomial functions of the adjacency matrix. Explanations: [Graph Representation Learing: Chapter 7](https://www.cs.mcgill.ca/~wlh/grl_book/)

# %% [markdown]
# # **PyTorch Geometric: Introduction via Node Classification**
#
# *   Implementing GNNs with an adjacency matrix is simple and straightforward but can be computationally expensive for large graphs.
# *   **[PyTorch Geometric (PyG) library](https://github.com/rusty1s/pytorch_geometric)** is an extension to PyTorch, and consists of various methods and utilities for optimized and easy implementation of GNNs.
#
# #### **Dataset**
# PyTorch Geometric provides an easy access to the dataset via the [`torch_geometric.datasets`](https://pytorch-geometric.readthedocs.io/en/latest/modules/datasets.html#torch_geometric.datasets) subpackage.

# %%
from torch_geometric.datasets import Planetoid

dataset = Planetoid(root='data/Planetoid', name='Cora')
print(f'Dataset: {dataset}:')
print('=========================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Done!
# Dataset: Cora():
# =========================
# Number of graphs: 1
# Number of features: 1433
# Number of classes: 7

# %% [markdown]
# We will use `Cora` dataset, which is a **citation network** where nodes represent documents. Each node is described by a 1433-dimensional bag-of-words feature vector. Two documents are connected if there exists a citation link between them.

# %% [markdown]
# We can extract the first (and the only) graph, represented by PyG class [Data](https://pytorch-geometric.readthedocs.io/en/latest/modules/data.html#torch_geometric.data.Data), from the dataset object and gather some statistics about it.

# %%
data = dataset[0]  # Get the first graph object.

print(data)
print('==============================================================')

# Gather some statistics about the graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {(data.num_edges) / (2 * data.num_nodes):.2f}')
print(f'Number of training nodes: {data.train_mask.sum()}')
print(f'Training node label rate: {int(data.train_mask.sum()) / data.num_nodes:.2f}')
print(f'Contains isolated nodes: {data.has_isolated_nodes()}')
print(f'Contains self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])
# ==============================================================
# Number of nodes: 2708
# Number of edges: 10556
# Average node degree: 1.95
# Number of training nodes: 140
# Training node label rate: 0.05
# Contains isolated nodes: False
# Contains self-loops: False
# Is undirected: True

# %% [markdown]
# The `train_mask`, `val_mask`, and `test_mask` are boolean masks that indicate which nodes we should use for training, validation, and testing

# %% [markdown]
# #### **Edge index**
#
# *   We represent node connectivity via the `edge_index` tensor.
# *   Printing its transposed version shows us the edges between nodes, e.g. $[0, 633]$ means that there's an edge between node $0$ and node $633$.
# *   The edge is shown twice for an undirected graph, but the positions of its values are switched, e.g. $[633, 0]$.
# *   If a graph is directed, then there is an edge only one edge corresponding to each edge direction, e.g. $[0, 633]$ **only**.

# %%
from IPython.display import Javascript  # Restrict height of output cell.

display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))
edge_index = data.edge_index
print(edge_index.t()[:100])
# Out:
# tensor([[ 633,    0],
#         [1862,    0],
#         [2582,    0],
#         [   2,    1],
#         [ 652,    1],
#         [ 654,    1],
#         [   1,    2],
#         [ 332,    2],
#         [1454,    2],
#         [1666,    2],
#         [1986,    2],
#         [2544,    3],
#         [1016,    4],
#         [1256,    4],
#         [1761,    4],
#         [2175,    4],
#         [2176,    4],
#         [1629,    5],
#         [1659,    5],
#         [2546,    5],
#         [ 373,    6],
#         [1042,    6],
#         [1416,    6],
#         [1602,    6],
#         [ 208,    7],
#         [ 269,    8],
#         [ 281,    8],
#         [1996,    8],
#         [ 723,    9],
#         [2614,    9],
#         [ 476,   10],
#         [2545,   10],
#         [1655,   11],
#         [1839,   11],
#         [1001,   12],
#         [1318,   12],
#         [2661,   12],
#         [2662,   12],
#         [1701,   13],
#         [1810,   13],
#         [ 158,   14],
#         [2034,   14],
#         [2075,   14],
#         [2077,   14],
#         [2668,   14],
#         [1090,   15],
#         [1093,   15],
#         [1271,   15],
#         [2367,   15],
#         [ 970,   16],
#         [1632,   16],
#         [2444,   16],
#         [2642,   16],
#         [  24,   17],
#         [ 927,   17],
#         [1315,   17],
#         [1316,   17],
#         [2140,   17],
#         [ 139,   18],
#         [1560,   18],
#         [1786,   18],
#         [2082,   18],
#         [2145,   18],
#         [1939,   19],
#         [1072,   20],
#         [2269,   20],
#         [2270,   20],
#         [2374,   20],
#         [2375,   20],
#         [1043,   21],
#         [2310,   21],
#         [  39,   22],
#         [1234,   22],
#         [1702,   22],
#         [1703,   22],
#         [2238,   22],
#         [2159,   23],
#         [  17,   24],
#         [ 201,   24],
#         [ 598,   24],
#         [1636,   24],
#         [1701,   24],
#         [2139,   24],
#         [2141,   24],
#         [1301,   25],
#         [1344,   25],
#         [2011,   25],
#         [2317,   25],
#         [  99,   26],
#         [ 122,   26],
#         [ 123,   26],
#         [2454,   26],
#         [2455,   26],
#         [ 606,   27],
#         [1810,   27],
#         [2360,   27],
#         [2578,   27],
#         [1687,   28],
#         [ 963,   29],
#         [2645,   29]])

# %% [markdown]
# This representation is known as the **COO format (coordinate format)** commonly used for representing sparse matrices.

# %% [markdown]
# ## **Node classification**
#
# The task is to infer the category of each document (7 in total), having only a small fraction, 5%, of labeled nodes in the training set.
#
# Let's create an MLP baseline that is applied to each node independently. This way we can verify whether adding the graph information to the model indeed improves the prediction or not. However, it might also be that the features per node are already expressive enough to clearly point towards a specific class.

# %%
from torch.nn import Linear, Dropout, ReLU

class MLP(torch.nn.Module):
    def __init__(self, c_in, c_out, c_hidden):
        super().__init__()
        torch.manual_seed(12345)
        self.lin1 = Linear(c_in, c_hidden)
        self.lin2 = Linear(c_hidden, c_out)
        self.dropout = Dropout(p=0.5, inplace=False)

    def forward(self, x):
        x = self.lin1(x)
        x = ReLU()(x)
        x = self.dropout(x)
        return self.lin2(x)

c_in = dataset.num_features
c_out = dataset.num_classes
model = MLP(c_in=c_in, c_out=c_out, c_hidden=16)
print(model)
# Out:
# MLP(
#   (lin1): Linear(in_features=1433, out_features=16, bias=True)
#   (lin2): Linear(in_features=16, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %% [markdown]
# We can visualize the 7-dimensional node embeddings that out untrained model produces, using the [TSNE](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html) package that projects a high-dimensional data onto a low-dimensional plane in such a way that similar points are put close to each other.

# %%
model.eval()

out = model(data.x)
visualize(out, color=data.y)

# %% [markdown]
# **As expected, the untrained model fails to separate the classes and produces similar embeddings for all 7 paper categories.**

# %% [markdown]
# Let's train the MLP model:

# %%
from IPython.display import Javascript  # Restrict height of output cell.
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

# Train MLP:
c_in = dataset.num_features
c_out = dataset.num_classes
mlp_model = MLP(c_in=c_in, c_out=c_out, c_hidden=16)
loss_function = torch.nn.CrossEntropyLoss()  # Define loss function.
optimizer = torch.optim.Adam(mlp_model.parameters(), lr=0.01, weight_decay=5e-4)  # Define optimizer.

def train():
    mlp_model.train()  # Set the model to the train mode
    optimizer.zero_grad()  # Clear gradients.
    out = mlp_model(data.x)  # Perform a single forward pass.
    loss = loss_function(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
    loss.backward()  # Derive gradients.
    optimizer.step()  # Update parameters based on gradients.
    return loss

def test(mask):
    mlp_model.eval() # Set model to evaluation mode
    out = mlp_model(data.x)
    pred = out.argmax(dim=1)  # Use the class with the highest probability.
    correct = pred[mask] == data.y[mask]  # Check against ground-truth labels.
    acc = int(correct.sum()) / int(mask.sum())  # Derive ratio of correct predictions.
    return acc

for epoch in range(1, 201):
    train()
    train_acc = test(data.train_mask)
    val_acc= test(data.val_mask)
    test_acc = test(data.test_mask)
    print(
     f'Epoch: {epoch:03d}, Train acc: {train_acc:.4f}, '
     f'Val acc: {val_acc:.4f}, Test acc: {test_acc:4f}'
    )
# Out:
# Epoch: 001, Train acc: 0.2143, Val acc: 0.1060, Test acc: 0.107000
# Epoch: 002, Train acc: 0.3429, Val acc: 0.1080, Test acc: 0.111000
# Epoch: 003, Train acc: 0.6357, Val acc: 0.1480, Test acc: 0.161000
# Epoch: 004, Train acc: 0.7714, Val acc: 0.2440, Test acc: 0.236000
# Epoch: 005, Train acc: 0.8714, Val acc: 0.3380, Test acc: 0.320000
# Epoch: 006, Train acc: 0.9214, Val acc: 0.4160, Test acc: 0.391000
# Epoch: 007, Train acc: 0.9571, Val acc: 0.4500, Test acc: 0.443000
# Epoch: 008, Train acc: 0.9714, Val acc: 0.4840, Test acc: 0.460000
# Epoch: 009, Train acc: 0.9714, Val acc: 0.5120, Test acc: 0.495000
# Epoch: 010, Train acc: 0.9714, Val acc: 0.5420, Test acc: 0.512000
# Epoch: 011, Train acc: 0.9857, Val acc: 0.5500, Test acc: 0.515000
# Epoch: 012, Train acc: 0.9857, Val acc: 0.5560, Test acc: 0.522000
# Epoch: 013, Train acc: 0.9857, Val acc: 0.5600, Test acc: 0.522000
# Epoch: 014, Train acc: 0.9857, Val acc: 0.5540, Test acc: 0.525000
# Epoch: 015, Train acc: 0.9929, Val acc: 0.5580, Test acc: 0.533000
# Epoch: 016, Train acc: 0.9929, Val acc: 0.5620, Test acc: 0.535000
# Epoch: 017, Train acc: 0.9929, Val acc: 0.5560, Test acc: 0.535000
# Epoch: 018, Train acc: 1.0000, Val acc: 0.5620, Test acc: 0.539000
# Epoch: 019, Train acc: 1.0000, Val acc: 0.5680, Test acc: 0.542000
# Epoch: 020, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.545000
# Epoch: 021, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.551000
# Epoch: 022, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.546000
# Epoch: 023, Train acc: 1.0000, Val acc: 0.5760, Test acc: 0.545000
# Epoch: 024, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.550000
# Epoch: 025, Train acc: 1.0000, Val acc: 0.5900, Test acc: 0.552000
# Epoch: 026, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.558000
# Epoch: 027, Train acc: 1.0000, Val acc: 0.5900, Test acc: 0.557000
# Epoch: 028, Train acc: 1.0000, Val acc: 0.5940, Test acc: 0.556000
# Epoch: 029, Train acc: 1.0000, Val acc: 0.5960, Test acc: 0.555000
# Epoch: 030, Train acc: 1.0000, Val acc: 0.5920, Test acc: 0.554000
# Epoch: 031, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.555000
# Epoch: 032, Train acc: 1.0000, Val acc: 0.5880, Test acc: 0.554000
# Epoch: 033, Train acc: 1.0000, Val acc: 0.5840, Test acc: 0.555000
# Epoch: 034, Train acc: 1.0000, Val acc: 0.5880, Test acc: 0.556000
# Epoch: 035, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.556000
# Epoch: 036, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.555000
# Epoch: 037, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.557000
# Epoch: 038, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.557000
# Epoch: 039, Train acc: 1.0000, Val acc: 0.5840, Test acc: 0.557000
# Epoch: 040, Train acc: 1.0000, Val acc: 0.5840, Test acc: 0.555000
# Epoch: 041, Train acc: 1.0000, Val acc: 0.5840, Test acc: 0.555000
# Epoch: 042, Train acc: 1.0000, Val acc: 0.5840, Test acc: 0.554000
# Epoch: 043, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.561000
# Epoch: 044, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.563000
# Epoch: 045, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.560000
# Epoch: 046, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.560000
# Epoch: 047, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.560000
# Epoch: 048, Train acc: 1.0000, Val acc: 0.5720, Test acc: 0.561000
# Epoch: 049, Train acc: 1.0000, Val acc: 0.5660, Test acc: 0.561000
# Epoch: 050, Train acc: 1.0000, Val acc: 0.5660, Test acc: 0.563000
# Epoch: 051, Train acc: 1.0000, Val acc: 0.5680, Test acc: 0.562000
# Epoch: 052, Train acc: 1.0000, Val acc: 0.5640, Test acc: 0.562000
# Epoch: 053, Train acc: 1.0000, Val acc: 0.5640, Test acc: 0.561000
# Epoch: 054, Train acc: 1.0000, Val acc: 0.5700, Test acc: 0.560000
# Epoch: 055, Train acc: 1.0000, Val acc: 0.5700, Test acc: 0.563000
# Epoch: 056, Train acc: 1.0000, Val acc: 0.5700, Test acc: 0.561000
# Epoch: 057, Train acc: 1.0000, Val acc: 0.5700, Test acc: 0.558000
# Epoch: 058, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.558000
# Epoch: 059, Train acc: 1.0000, Val acc: 0.5760, Test acc: 0.557000
# Epoch: 060, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.559000
# Epoch: 061, Train acc: 1.0000, Val acc: 0.5680, Test acc: 0.556000
# Epoch: 062, Train acc: 1.0000, Val acc: 0.5620, Test acc: 0.557000
# Epoch: 063, Train acc: 1.0000, Val acc: 0.5600, Test acc: 0.556000
# Epoch: 064, Train acc: 1.0000, Val acc: 0.5560, Test acc: 0.557000
# Epoch: 065, Train acc: 1.0000, Val acc: 0.5560, Test acc: 0.555000
# Epoch: 066, Train acc: 1.0000, Val acc: 0.5560, Test acc: 0.556000
# Epoch: 067, Train acc: 1.0000, Val acc: 0.5540, Test acc: 0.556000
# Epoch: 068, Train acc: 1.0000, Val acc: 0.5540, Test acc: 0.555000
# Epoch: 069, Train acc: 1.0000, Val acc: 0.5580, Test acc: 0.553000
# Epoch: 070, Train acc: 1.0000, Val acc: 0.5580, Test acc: 0.553000
# Epoch: 071, Train acc: 1.0000, Val acc: 0.5560, Test acc: 0.550000
# Epoch: 072, Train acc: 1.0000, Val acc: 0.5600, Test acc: 0.551000
# Epoch: 073, Train acc: 1.0000, Val acc: 0.5600, Test acc: 0.549000
# Epoch: 074, Train acc: 1.0000, Val acc: 0.5620, Test acc: 0.551000
# Epoch: 075, Train acc: 1.0000, Val acc: 0.5640, Test acc: 0.550000
# Epoch: 076, Train acc: 1.0000, Val acc: 0.5620, Test acc: 0.550000
# Epoch: 077, Train acc: 1.0000, Val acc: 0.5620, Test acc: 0.545000
# Epoch: 078, Train acc: 1.0000, Val acc: 0.5660, Test acc: 0.549000
# Epoch: 079, Train acc: 1.0000, Val acc: 0.5620, Test acc: 0.549000
# Epoch: 080, Train acc: 1.0000, Val acc: 0.5660, Test acc: 0.552000
# Epoch: 081, Train acc: 1.0000, Val acc: 0.5660, Test acc: 0.556000
# Epoch: 082, Train acc: 1.0000, Val acc: 0.5680, Test acc: 0.558000
# Epoch: 083, Train acc: 1.0000, Val acc: 0.5720, Test acc: 0.557000
# Epoch: 084, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.558000
# Epoch: 085, Train acc: 1.0000, Val acc: 0.5720, Test acc: 0.561000
# Epoch: 086, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.561000
# Epoch: 087, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.557000
# Epoch: 088, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.558000
# Epoch: 089, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.558000
# Epoch: 090, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.556000
# Epoch: 091, Train acc: 1.0000, Val acc: 0.5760, Test acc: 0.560000
# Epoch: 092, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.562000
# Epoch: 093, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.562000
# Epoch: 094, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.561000
# Epoch: 095, Train acc: 1.0000, Val acc: 0.5760, Test acc: 0.561000
# Epoch: 096, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.559000
# Epoch: 097, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.561000
# Epoch: 098, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.560000
# Epoch: 099, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.559000
# Epoch: 100, Train acc: 1.0000, Val acc: 0.5760, Test acc: 0.561000
# Epoch: 101, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.563000
# Epoch: 102, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.565000
# Epoch: 103, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.567000
# Epoch: 104, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.564000
# Epoch: 105, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.557000
# Epoch: 106, Train acc: 1.0000, Val acc: 0.5760, Test acc: 0.554000
# Epoch: 107, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.552000
# Epoch: 108, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.553000
# Epoch: 109, Train acc: 1.0000, Val acc: 0.5720, Test acc: 0.554000
# Epoch: 110, Train acc: 1.0000, Val acc: 0.5700, Test acc: 0.556000
# Epoch: 111, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.555000
# Epoch: 112, Train acc: 1.0000, Val acc: 0.5760, Test acc: 0.558000
# Epoch: 113, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.558000
# Epoch: 114, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.559000
# Epoch: 115, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.562000
# Epoch: 116, Train acc: 1.0000, Val acc: 0.5760, Test acc: 0.565000
# Epoch: 117, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.565000
# Epoch: 118, Train acc: 1.0000, Val acc: 0.5760, Test acc: 0.567000
# Epoch: 119, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.567000
# Epoch: 120, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.568000
# Epoch: 121, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.569000
# Epoch: 122, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.566000
# Epoch: 123, Train acc: 1.0000, Val acc: 0.5760, Test acc: 0.566000
# Epoch: 124, Train acc: 1.0000, Val acc: 0.5760, Test acc: 0.567000
# Epoch: 125, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.570000
# Epoch: 126, Train acc: 1.0000, Val acc: 0.5760, Test acc: 0.572000
# Epoch: 127, Train acc: 1.0000, Val acc: 0.5760, Test acc: 0.572000
# Epoch: 128, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.569000
# Epoch: 129, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.566000
# Epoch: 130, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.567000
# Epoch: 131, Train acc: 1.0000, Val acc: 0.5840, Test acc: 0.569000
# Epoch: 132, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.566000
# Epoch: 133, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.566000
# Epoch: 134, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.568000
# Epoch: 135, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.570000
# Epoch: 136, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.571000
# Epoch: 137, Train acc: 1.0000, Val acc: 0.5840, Test acc: 0.570000
# Epoch: 138, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.572000
# Epoch: 139, Train acc: 1.0000, Val acc: 0.5840, Test acc: 0.573000
# Epoch: 140, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.572000
# Epoch: 141, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.572000
# Epoch: 142, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.572000
# Epoch: 143, Train acc: 1.0000, Val acc: 0.5880, Test acc: 0.571000
# Epoch: 144, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.573000
# Epoch: 145, Train acc: 1.0000, Val acc: 0.5840, Test acc: 0.575000
# Epoch: 146, Train acc: 1.0000, Val acc: 0.5880, Test acc: 0.574000
# Epoch: 147, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.576000
# Epoch: 148, Train acc: 1.0000, Val acc: 0.5840, Test acc: 0.576000
# Epoch: 149, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.577000
# Epoch: 150, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.575000
# Epoch: 151, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.572000
# Epoch: 152, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.573000
# Epoch: 153, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.576000
# Epoch: 154, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.575000
# Epoch: 155, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.574000
# Epoch: 156, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.570000
# Epoch: 157, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.569000
# Epoch: 158, Train acc: 1.0000, Val acc: 0.5840, Test acc: 0.569000
# Epoch: 159, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.570000
# Epoch: 160, Train acc: 1.0000, Val acc: 0.5880, Test acc: 0.569000
# Epoch: 161, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.571000
# Epoch: 162, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.567000
# Epoch: 163, Train acc: 1.0000, Val acc: 0.5880, Test acc: 0.567000
# Epoch: 164, Train acc: 1.0000, Val acc: 0.5880, Test acc: 0.568000
# Epoch: 165, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.569000
# Epoch: 166, Train acc: 1.0000, Val acc: 0.5840, Test acc: 0.570000
# Epoch: 167, Train acc: 1.0000, Val acc: 0.5840, Test acc: 0.567000
# Epoch: 168, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.568000
# Epoch: 169, Train acc: 1.0000, Val acc: 0.5880, Test acc: 0.568000
# Epoch: 170, Train acc: 1.0000, Val acc: 0.5920, Test acc: 0.568000
# Epoch: 171, Train acc: 1.0000, Val acc: 0.5920, Test acc: 0.570000
# Epoch: 172, Train acc: 1.0000, Val acc: 0.5900, Test acc: 0.573000
# Epoch: 173, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.576000
# Epoch: 174, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.577000
# Epoch: 175, Train acc: 1.0000, Val acc: 0.5860, Test acc: 0.582000
# Epoch: 176, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.579000
# Epoch: 177, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.575000
# Epoch: 178, Train acc: 1.0000, Val acc: 0.5840, Test acc: 0.574000
# Epoch: 179, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.573000
# Epoch: 180, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.573000
# Epoch: 181, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.574000
# Epoch: 182, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.577000
# Epoch: 183, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.575000
# Epoch: 184, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.578000
# Epoch: 185, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.578000
# Epoch: 186, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.579000
# Epoch: 187, Train acc: 1.0000, Val acc: 0.5800, Test acc: 0.579000
# Epoch: 188, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.581000
# Epoch: 189, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.581000
# Epoch: 190, Train acc: 1.0000, Val acc: 0.5820, Test acc: 0.579000
# Epoch: 191, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.579000
# Epoch: 192, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.574000
# Epoch: 193, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.573000
# Epoch: 194, Train acc: 1.0000, Val acc: 0.5780, Test acc: 0.573000
# Epoch: 195, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.574000
# Epoch: 196, Train acc: 1.0000, Val acc: 0.5720, Test acc: 0.576000
# Epoch: 197, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.577000
# Epoch: 198, Train acc: 1.0000, Val acc: 0.5760, Test acc: 0.580000
# Epoch: 199, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.582000
# Epoch: 200, Train acc: 1.0000, Val acc: 0.5740, Test acc: 0.583000

# %% [markdown]
# **Reasons for poor MLP performance**
#
# *   **Strong overfitting** due to only having access to a **small amount of training nodes**, that leads to poor generalization on the unseen nodes.
# *   It also fails to incorporate an important inductive bias into the model: **Papers belonging to the same category are most likely to have a citation relation (edge) between them** $\to$ we can use a GNN to incorporate this information.

# %%
from torch_geometric.nn import GCNConv

class GCN(torch.nn.Module):

    def __init__(self, c_in, c_out, c_hidden):
        super().__init__()
        torch.manual_seed(12345)
        self.conv1 = GCNConv(c_in, c_hidden)
        self.conv2 = GCNConv(c_hidden, c_out)
        self.dropout = Dropout(p=0.5, inplace=False)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = ReLU()(x)
        x = self.dropout(x)
        return self.conv2(x, edge_index)

c_in = dataset.num_features
c_out = dataset.num_classes
model = GCN(c_in=c_in, c_out=c_out, c_hidden=16)
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(1433, 16)
#   (conv2): GCNConv(16, 7)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
c_in = dataset.num_features
c_out = dataset.num_classes

mlp = MLP(c_in=c_in, c_out=c_out, c_hidden=256)
gcn = GCN(c_in=c_in, c_out=c_out, c_hidden=256)

mlp.eval()
gcn.eval()

out_mlp = mlp(data.x)
mlp_title = 'Untrained MLP embeddings'

out_gcn = gcn(data.x, data.edge_index)
gcn_title = 'Untrained GCN embeddings'

visualize_both(out_mlp, out_gcn, mlp_title, gcn_title, color=data.y)

# %% [markdown]
# ### **Exercise 2.1: MLP vs GCN untrained embeddings**
#
# *   Create two new models, MLP and GCN, i.e. instances of the corresponding classes, using the same number of input/hidden/output channels. Please, use `c_hidden=256` for both models and name a new MLP model differently, so the trained model stays untouched, we will need it for later.
# *   Following the example above, plot the lower dimensional representation of the node embeddings produced by the both models.
#   - **hint:** don't forget to set the models to the evaluation mode. This will turn the dropout off.
#   - **hint:** make use of the function `visualize_both` defined in the imports.
# * Answer the following questions:
#   - What is the difference between the embeddings?
#   - Why do you think this difference exists?
#   - What conclusions about GCNs can you draw?

# %% [markdown]
# #### **[The Weisfeiler-Lehman Isomorphism Test](https://davidbieber.com/post/2019-05-10-weisfeiler-lehman-isomorphism-test/)**
#
# <center width="100%" style="padding:10px"> <img src ="https://drive.google.com/uc?id=1ar2xbg4lz0_-AjkT0Ic2EEHZKyXl2Mjl" width="600px"></center>
#
# > "*Two graphs are considered isomorphic if there is a mapping between the nodes of the graphs that preserves node adjacencies.*"
#
# **Algorithm:**
#
# 1.   Intialize all nodes features to 1.
# 2.   Get features $\{ h_{v_j} \}$ of neighboring nodes $\{ v_j \}$
# 3.   Update node feature $h_{v_i} \leftarrow \text{hash} (\sum_j h_{v_j})$
# 4.   Partition the nodes in the graph by their features. Repeat 2 + 3 for up to  (the number of nodes) iterations, or until there is no change in the partition of nodes by features from one iteration to the next.
#
# If the partitions of two graphs are the same, then the graphs can be isomorphic.
#
# *   Graph Convolutional layer-wise propagation rule in vector form:
# $$h_{v_i}^{(l+1)} = \sigma (\sum_j \frac{1}{c_{ij}}  h_{v_j}^{(l)} W^{(l)}),$$
# where $c_{ij}$ is a normalization constant for the edge.
#
# *  The propagation rule can be interpreted as a differentiable and parametrized (with W(l)) variant of the hash function used in the Weisfeiler-Lehman algorithm.
#
# **We get meaningful smooth embeddings where we can interpret distance as (dis-)similarity of local graph structures!**

# %% [markdown]
# ### **Exercise 2.2: Train and visualize GCN**
#
# *   Write code for training the GCN model.
#   - **hint:** Modify the code for MLP training so that it runs with the GCN model.
#   - **hint:** Use the same number of hidden channels.
# *   Compare the results of the GCN and MLP.
# *   Visualize trained embeddings of MLP and GCN.
#   - **hint:** You can reuse the code from Exercise 2.1, you just need to use the trained models. Don't forget to set them to the eval mode.

# %%
c_in = dataset.num_features
c_out = dataset.num_classes
gcn_model = GCN(c_in=c_in, c_out=c_out, c_hidden=16)
loss_function = torch.nn.CrossEntropyLoss()  # Define loss function.
optimizer = torch.optim.Adam(gcn_model.parameters(), lr=0.01, weight_decay=5e-4)  # Define optimizer.

def train():
      gcn_model.train()
      optimizer.zero_grad()  # Clear gradients.
      out = gcn_model(data.x, data.edge_index)  # Perform a single forward pass.
      loss = loss_function(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
      loss.backward()  # Derive gradients.
      optimizer.step()  # Update parameters based on gradients.
      return loss

def test(mask):
      gcn_model.eval() # Set model to evalutation mode
      out = gcn_model(data.x, data.edge_index)
      pred = out.argmax(dim=1)  # Use the class with highest probability.
      correct = pred[mask] == data.y[mask]  # Check against ground-truth labels.
      acc = int(correct.sum()) / int(mask.sum())  # Derive ratio of correct predictions.
      return acc

for epoch in range(1, 201):
    train()
    train_acc = test(data.train_mask)
    val_acc= test(data.val_mask)
    test_acc = test(data.test_mask)
    print(
      f'Epoch: {epoch:03d}, Train acc: {train_acc:.4f}, '
      f'Val acc: {val_acc:.4f}, Test acc: {test_acc:4f}'
    )

# Visualize the trained MLP vs GCN
c_in = dataset.num_features
c_out = dataset.num_classes

mlp_model.eval()
gcn_model.eval()

out_mlp = mlp_model(data.x)
mlp_title = 'Trained MLP embeddings'

out_gcn = gcn_model(data.x, data.edge_index)
gcn_title = 'Trained GCN embeddings'

visualize_both(out_mlp, out_gcn, mlp_title, gcn_title, color=data.y)
# Out:
# Epoch: 001, Train acc: 0.6643, Val acc: 0.4760, Test acc: 0.486000
# Epoch: 002, Train acc: 0.8000, Val acc: 0.5520, Test acc: 0.579000
# Epoch: 003, Train acc: 0.8357, Val acc: 0.5680, Test acc: 0.610000
# Epoch: 004, Train acc: 0.9000, Val acc: 0.6080, Test acc: 0.642000
# Epoch: 005, Train acc: 0.9071, Val acc: 0.6480, Test acc: 0.676000
# Epoch: 006, Train acc: 0.9357, Val acc: 0.6860, Test acc: 0.705000
# Epoch: 007, Train acc: 0.9500, Val acc: 0.7160, Test acc: 0.729000
# Epoch: 008, Train acc: 0.9571, Val acc: 0.7280, Test acc: 0.749000
# Epoch: 009, Train acc: 0.9571, Val acc: 0.7300, Test acc: 0.759000
# Epoch: 010, Train acc: 0.9643, Val acc: 0.7480, Test acc: 0.757000
# Epoch: 011, Train acc: 0.9786, Val acc: 0.7500, Test acc: 0.766000
# Epoch: 012, Train acc: 0.9786, Val acc: 0.7600, Test acc: 0.768000
# Epoch: 013, Train acc: 0.9857, Val acc: 0.7700, Test acc: 0.778000
# Epoch: 014, Train acc: 0.9857, Val acc: 0.7760, Test acc: 0.786000
# Epoch: 015, Train acc: 0.9857, Val acc: 0.7900, Test acc: 0.789000
# Epoch: 016, Train acc: 0.9857, Val acc: 0.7900, Test acc: 0.791000
# Epoch: 017, Train acc: 0.9857, Val acc: 0.7880, Test acc: 0.793000
# Epoch: 018, Train acc: 0.9857, Val acc: 0.7840, Test acc: 0.796000
# Epoch: 019, Train acc: 0.9857, Val acc: 0.7880, Test acc: 0.797000
# Epoch: 020, Train acc: 0.9929, Val acc: 0.7900, Test acc: 0.797000
# Epoch: 021, Train acc: 0.9929, Val acc: 0.7900, Test acc: 0.794000
# Epoch: 022, Train acc: 0.9929, Val acc: 0.7900, Test acc: 0.795000
# Epoch: 023, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.796000
# Epoch: 024, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.797000
# Epoch: 025, Train acc: 1.0000, Val acc: 0.7940, Test acc: 0.799000
# Epoch: 026, Train acc: 1.0000, Val acc: 0.7960, Test acc: 0.797000
# Epoch: 027, Train acc: 1.0000, Val acc: 0.7940, Test acc: 0.798000
# Epoch: 028, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.793000
# Epoch: 029, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.793000
# Epoch: 030, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.790000
# Epoch: 031, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.790000
# Epoch: 032, Train acc: 1.0000, Val acc: 0.7920, Test acc: 0.788000
# Epoch: 033, Train acc: 1.0000, Val acc: 0.7920, Test acc: 0.792000
# Epoch: 034, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.794000
# Epoch: 035, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.794000
# Epoch: 036, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.793000
# Epoch: 037, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.793000
# Epoch: 038, Train acc: 1.0000, Val acc: 0.7800, Test acc: 0.793000
# Epoch: 039, Train acc: 1.0000, Val acc: 0.7780, Test acc: 0.793000
# Epoch: 040, Train acc: 1.0000, Val acc: 0.7800, Test acc: 0.791000
# Epoch: 041, Train acc: 1.0000, Val acc: 0.7780, Test acc: 0.790000
# Epoch: 042, Train acc: 1.0000, Val acc: 0.7760, Test acc: 0.789000
# Epoch: 043, Train acc: 1.0000, Val acc: 0.7760, Test acc: 0.788000
# Epoch: 044, Train acc: 1.0000, Val acc: 0.7760, Test acc: 0.787000
# Epoch: 045, Train acc: 1.0000, Val acc: 0.7760, Test acc: 0.784000
# Epoch: 046, Train acc: 1.0000, Val acc: 0.7760, Test acc: 0.785000
# Epoch: 047, Train acc: 1.0000, Val acc: 0.7780, Test acc: 0.783000
# Epoch: 048, Train acc: 1.0000, Val acc: 0.7760, Test acc: 0.784000
# Epoch: 049, Train acc: 1.0000, Val acc: 0.7760, Test acc: 0.785000
# Epoch: 050, Train acc: 1.0000, Val acc: 0.7780, Test acc: 0.786000
# Epoch: 051, Train acc: 1.0000, Val acc: 0.7800, Test acc: 0.787000
# Epoch: 052, Train acc: 1.0000, Val acc: 0.7760, Test acc: 0.788000
# Epoch: 053, Train acc: 1.0000, Val acc: 0.7740, Test acc: 0.789000
# Epoch: 054, Train acc: 1.0000, Val acc: 0.7740, Test acc: 0.791000
# Epoch: 055, Train acc: 1.0000, Val acc: 0.7740, Test acc: 0.793000
# Epoch: 056, Train acc: 1.0000, Val acc: 0.7780, Test acc: 0.797000
# Epoch: 057, Train acc: 1.0000, Val acc: 0.7800, Test acc: 0.798000
# Epoch: 058, Train acc: 1.0000, Val acc: 0.7820, Test acc: 0.798000
# Epoch: 059, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.803000
# Epoch: 060, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.808000
# Epoch: 061, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.809000
# Epoch: 062, Train acc: 1.0000, Val acc: 0.7920, Test acc: 0.809000
# Epoch: 063, Train acc: 1.0000, Val acc: 0.7920, Test acc: 0.810000
# Epoch: 064, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.809000
# Epoch: 065, Train acc: 1.0000, Val acc: 0.7920, Test acc: 0.807000
# Epoch: 066, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.807000
# Epoch: 067, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.807000
# Epoch: 068, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.804000
# Epoch: 069, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.803000
# Epoch: 070, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.800000
# Epoch: 071, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.798000
# Epoch: 072, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.796000
# Epoch: 073, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.797000
# Epoch: 074, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.796000
# Epoch: 075, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.795000
# Epoch: 076, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.794000
# Epoch: 077, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.795000
# Epoch: 078, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.797000
# Epoch: 079, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.801000
# Epoch: 080, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.802000
# Epoch: 081, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.803000
# Epoch: 082, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.803000
# Epoch: 083, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.803000
# Epoch: 084, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.802000
# Epoch: 085, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.802000
# Epoch: 086, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.802000
# Epoch: 087, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.804000
# Epoch: 088, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.802000
# Epoch: 089, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.803000
# Epoch: 090, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.803000
# Epoch: 091, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.803000
# Epoch: 092, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.802000
# Epoch: 093, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.801000
# Epoch: 094, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.800000
# Epoch: 095, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.799000
# Epoch: 096, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.795000
# Epoch: 097, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.796000
# Epoch: 098, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.798000
# Epoch: 099, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.797000
# Epoch: 100, Train acc: 1.0000, Val acc: 0.7820, Test acc: 0.800000
# Epoch: 101, Train acc: 1.0000, Val acc: 0.7820, Test acc: 0.800000
# Epoch: 102, Train acc: 1.0000, Val acc: 0.7820, Test acc: 0.796000
# Epoch: 103, Train acc: 1.0000, Val acc: 0.7820, Test acc: 0.796000
# Epoch: 104, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.799000
# Epoch: 105, Train acc: 1.0000, Val acc: 0.7820, Test acc: 0.800000
# Epoch: 106, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.801000
# Epoch: 107, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.804000
# Epoch: 108, Train acc: 1.0000, Val acc: 0.7920, Test acc: 0.802000
# Epoch: 109, Train acc: 1.0000, Val acc: 0.7960, Test acc: 0.801000
# Epoch: 110, Train acc: 1.0000, Val acc: 0.7940, Test acc: 0.805000
# Epoch: 111, Train acc: 1.0000, Val acc: 0.7920, Test acc: 0.805000
# Epoch: 112, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.803000
# Epoch: 113, Train acc: 1.0000, Val acc: 0.7920, Test acc: 0.805000
# Epoch: 114, Train acc: 1.0000, Val acc: 0.7920, Test acc: 0.806000
# Epoch: 115, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.804000
# Epoch: 116, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.806000
# Epoch: 117, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.808000
# Epoch: 118, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.807000
# Epoch: 119, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.806000
# Epoch: 120, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.804000
# Epoch: 121, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.802000
# Epoch: 122, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.801000
# Epoch: 123, Train acc: 1.0000, Val acc: 0.7820, Test acc: 0.800000
# Epoch: 124, Train acc: 1.0000, Val acc: 0.7800, Test acc: 0.801000
# Epoch: 125, Train acc: 1.0000, Val acc: 0.7820, Test acc: 0.800000
# Epoch: 126, Train acc: 1.0000, Val acc: 0.7820, Test acc: 0.802000
# Epoch: 127, Train acc: 1.0000, Val acc: 0.7820, Test acc: 0.800000
# Epoch: 128, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.796000
# Epoch: 129, Train acc: 1.0000, Val acc: 0.7820, Test acc: 0.797000
# Epoch: 130, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.798000
# Epoch: 131, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.798000
# Epoch: 132, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.797000
# Epoch: 133, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.799000
# Epoch: 134, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.799000
# Epoch: 135, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.799000
# Epoch: 136, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.801000
# Epoch: 137, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.801000
# Epoch: 138, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.802000
# Epoch: 139, Train acc: 1.0000, Val acc: 0.7800, Test acc: 0.799000
# Epoch: 140, Train acc: 1.0000, Val acc: 0.7780, Test acc: 0.797000
# Epoch: 141, Train acc: 1.0000, Val acc: 0.7820, Test acc: 0.800000
# Epoch: 142, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.800000
# Epoch: 143, Train acc: 1.0000, Val acc: 0.7920, Test acc: 0.803000
# Epoch: 144, Train acc: 1.0000, Val acc: 0.7940, Test acc: 0.806000
# Epoch: 145, Train acc: 1.0000, Val acc: 0.7960, Test acc: 0.807000
# Epoch: 146, Train acc: 1.0000, Val acc: 0.7960, Test acc: 0.803000
# Epoch: 147, Train acc: 1.0000, Val acc: 0.7940, Test acc: 0.804000
# Epoch: 148, Train acc: 1.0000, Val acc: 0.7960, Test acc: 0.805000
# Epoch: 149, Train acc: 1.0000, Val acc: 0.7940, Test acc: 0.805000
# Epoch: 150, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.806000
# Epoch: 151, Train acc: 1.0000, Val acc: 0.7920, Test acc: 0.804000
# Epoch: 152, Train acc: 1.0000, Val acc: 0.7940, Test acc: 0.804000
# Epoch: 153, Train acc: 1.0000, Val acc: 0.7940, Test acc: 0.806000
# Epoch: 154, Train acc: 1.0000, Val acc: 0.7940, Test acc: 0.806000
# Epoch: 155, Train acc: 1.0000, Val acc: 0.7960, Test acc: 0.807000
# Epoch: 156, Train acc: 1.0000, Val acc: 0.7940, Test acc: 0.806000
# Epoch: 157, Train acc: 1.0000, Val acc: 0.7920, Test acc: 0.805000
# Epoch: 158, Train acc: 1.0000, Val acc: 0.7900, Test acc: 0.800000
# Epoch: 159, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.800000
# Epoch: 160, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.799000
# Epoch: 161, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.798000
# Epoch: 162, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.797000
# Epoch: 163, Train acc: 1.0000, Val acc: 0.7820, Test acc: 0.797000
# Epoch: 164, Train acc: 1.0000, Val acc: 0.7760, Test acc: 0.799000
# Epoch: 165, Train acc: 1.0000, Val acc: 0.7740, Test acc: 0.797000
# Epoch: 166, Train acc: 1.0000, Val acc: 0.7720, Test acc: 0.797000
# Epoch: 167, Train acc: 1.0000, Val acc: 0.7740, Test acc: 0.798000
# Epoch: 168, Train acc: 1.0000, Val acc: 0.7780, Test acc: 0.803000
# Epoch: 169, Train acc: 1.0000, Val acc: 0.7800, Test acc: 0.804000
# Epoch: 170, Train acc: 1.0000, Val acc: 0.7820, Test acc: 0.805000
# Epoch: 171, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.808000
# Epoch: 172, Train acc: 1.0000, Val acc: 0.7920, Test acc: 0.802000
# Epoch: 173, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.802000
# Epoch: 174, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.803000
# Epoch: 175, Train acc: 1.0000, Val acc: 0.7860, Test acc: 0.804000
# Epoch: 176, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.803000
# Epoch: 177, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.800000
# Epoch: 178, Train acc: 1.0000, Val acc: 0.7920, Test acc: 0.802000
# Epoch: 179, Train acc: 1.0000, Val acc: 0.7940, Test acc: 0.803000
# Epoch: 180, Train acc: 1.0000, Val acc: 0.7960, Test acc: 0.806000
# Epoch: 181, Train acc: 1.0000, Val acc: 0.7980, Test acc: 0.810000
# Epoch: 182, Train acc: 1.0000, Val acc: 0.7920, Test acc: 0.810000
# Epoch: 183, Train acc: 1.0000, Val acc: 0.7880, Test acc: 0.812000
# Epoch: 184, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.811000
# Epoch: 185, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.812000
# Epoch: 186, Train acc: 1.0000, Val acc: 0.7800, Test acc: 0.810000
# Epoch: 187, Train acc: 1.0000, Val acc: 0.7780, Test acc: 0.812000
# Epoch: 188, Train acc: 1.0000, Val acc: 0.7780, Test acc: 0.808000
# Epoch: 189, Train acc: 1.0000, Val acc: 0.7800, Test acc: 0.810000
# Epoch: 190, Train acc: 1.0000, Val acc: 0.7820, Test acc: 0.809000
# Epoch: 191, Train acc: 1.0000, Val acc: 0.7840, Test acc: 0.809000
# Epoch: 192, Train acc: 1.0000, Val acc: 0.7780, Test acc: 0.808000
# Epoch: 193, Train acc: 1.0000, Val acc: 0.7800, Test acc: 0.804000
# Epoch: 194, Train acc: 1.0000, Val acc: 0.7740, Test acc: 0.803000
# Epoch: 195, Train acc: 1.0000, Val acc: 0.7720, Test acc: 0.802000
# Epoch: 196, Train acc: 1.0000, Val acc: 0.7680, Test acc: 0.797000
# Epoch: 197, Train acc: 1.0000, Val acc: 0.7760, Test acc: 0.795000
# Epoch: 198, Train acc: 1.0000, Val acc: 0.7780, Test acc: 0.795000
# Epoch: 199, Train acc: 1.0000, Val acc: 0.7760, Test acc: 0.795000
# Epoch: 200, Train acc: 1.0000, Val acc: 0.7780, Test acc: 0.802000
